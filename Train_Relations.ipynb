# %% [markdown]
# <a href="https://colab.research.google.com/github/PunkGoesPop/ML/blob/master/Train_Relations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

model.fit(xs, ys, epochs=50)

print(model.predict([8.0]))
# Out:
# Train on 6 samples
# Epoch 1/50
# 6/6 [==============================] - 0s 67ms/sample - loss: 38.0108
# Epoch 2/50
# 6/6 [==============================] - 0s 323us/sample - loss: 29.9096
# Epoch 3/50
# 6/6 [==============================] - 0s 303us/sample - loss: 23.5359
# Epoch 4/50
# 6/6 [==============================] - 0s 300us/sample - loss: 18.5213
# Epoch 5/50
# 6/6 [==============================] - 0s 321us/sample - loss: 14.5760
# Epoch 6/50
# 6/6 [==============================] - 0s 418us/sample - loss: 11.4719
# Epoch 7/50
# 6/6 [==============================] - 0s 322us/sample - loss: 9.0296
# Epoch 8/50
# 6/6 [==============================] - 0s 351us/sample - loss: 7.1081
# Epoch 9/50
# 6/6 [==============================] - 0s 315us/sample - loss: 5.5963
# Epoch 10/50
# 6/6 [==============================] - 0s 376us/sample - loss: 4.4068
# Epoch 11/50
# 6/6 [==============================] - 0s 406us/sample - loss: 3.4708
# Epoch 12/50
# ...
